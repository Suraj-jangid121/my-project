# %%
student = {
    "name": "Raghav",
    "class": "BCA",
    "age": 20
}

print("Dictionary:", student)
print("Student Name:", student["name"])
# Out:
# Dictionary: {'name': 'Raghav', 'class': 'BCA', 'age': 20}
# Student Name: Raghav

# %%
colors = ("Red", "Blue", "Green")

print("Tuple:", colors)
print("First Color:", colors[0])
# Out:
# Tuple: ('Red', 'Blue', 'Green')
# First Color: Red

# %%
def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    if b != 0:
        return a / b
    else:
        return "Division by zero is not possible"
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
print("Addition =", add(num1, num2))
print("Subtraction =", subtract(num1, num2))
print("Multiplication =", multiply(num1, num2))
print("Division =", divide(num1, num2))
# Out:
# Addition = 12345555.0
# Subtraction = 12343087.0
# Multiplication = 15232892114.0
# Division = 10003.501620745543

# %%
num = int(input("Enter a number: "))

original_num = num
reverse_num = 0
while num > 0:
    digit = num % 10
    reverse_num = reverse_num * 10 + digit
    num = num // 10
if original_num == reverse_num:
    print(original_num, "is a Palindrome Number")
else:
    print(original_num, "is not a Palindrome Number")
# Out:
# 1234 is not a Palindrome Number
